# %%
import numpy as np
import pandas as pd
import datetime, re, gc, os

# pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 1000)

## Data Path
fold_pth = "~/ds7900_spring23_team2/"
output_pth = fold_pth + "output_data/"

email_hist_pth = os.path.expanduser(fold_pth + "email_hist/email_hist.csv")
stay_hist_pth = os.path.expanduser(fold_pth + "stay_hist/stay_hist.csv")
members_pth = os.path.expanduser(fold_pth + "members/members.csv")

members_pth_process = os.path.expanduser(output_pth + "members.csv")

stay_hist_pth_process = os.path.expanduser(output_pth + "stay_hist.csv")
stay_hist_pth_process2 = os.path.expanduser(output_pth + "stay_hist2.csv")

email_hist_pth_process = os.path.expanduser(output_pth + "email_hist.csv")
email_hist_pth_process2 = os.path.expanduser(output_pth + "email_hist_proc.csv")
email_hist_pth_process3 = os.path.expanduser(output_pth + "email_hist_proc_partial_stay.csv")

final_df_pth = os.path.expanduser(output_pth + "final_email_df.csv")
temp_pth = os.path.expanduser(output_pth + "temp.csv")


final_01_2022_pth = os.path.expanduser(output_pth + "final_01_2022_df.csv")

# %%
def df_fillna(df):
    df["BUS_LEIS_IND"]=df["BUS_LEIS_IND"].fillna(-1)
    df["STAY_REVENUE_USD"]=df["STAY_REVENUE_USD"].fillna(0)
    df["total_rooms"]=df["total_rooms"].fillna(0)
    df["total_GUEST_QTY"]=df["total_GUEST_QTY"].fillna(0)
    df["TIME_BWTN_CONF_CKIN_DT"]=df["TIME_BWTN_CONF_CKIN_DT"].fillna(0)
    df["TIME_BWTN_CKIN_CKOUT_DT"]=df["TIME_BWTN_CKIN_CKOUT_DT"].fillna(0)
    df["CONF_DT_daysto_holiday"]=df["CONF_DT_daysto_holiday"].fillna(9)
    df["CK_IN_DT_daysto_holiday"]=df["CK_IN_DT_daysto_holiday"].fillna(9)
    df["CK_OUT_DT_daysto_holiday"]=df["CK_OUT_DT_daysto_holiday"].fillna(9)
    df["CONF_DT_nearest_holiday_dayofyear"]=df["CONF_DT_nearest_holiday_dayofyear"].fillna(-1)
    df["CK_IN_DT_nearest_holiday_dayofyear"]=df["CK_IN_DT_nearest_holiday_dayofyear"].fillna(-1)
    df["CK_OUT_DT_nearest_holiday_dayofyear"]=df["CK_OUT_DT_nearest_holiday_dayofyear"].fillna(-1)
    df["DIFFERENT_CONTINENT"]=df["DIFFERENT_CONTINENT"].fillna(-1)
    df["HTL_RGN_EMEAA"]=df["HTL_RGN_EMEAA"].fillna(-1)
    df["HTL_RGN_GCHINA"]=df["HTL_RGN_GCHINA"].fillna(-1)
    df["HTL_CHAIN_CATEGORY_CHN_CAT_1"]=df["HTL_CHAIN_CATEGORY_CHN_CAT_1"].fillna(-1)
    df["HTL_CHAIN_CATEGORY_CHN_CAT_2"]=df["HTL_CHAIN_CATEGORY_CHN_CAT_2"].fillna(-1)
    df["HTL_CHAIN_CATEGORY_CHN_CAT_3"]=df["HTL_CHAIN_CATEGORY_CHN_CAT_3"].fillna(-1)
    df["REWARD_NT_RN_1"]=df["REWARD_NT_RN_1"].fillna(-1)
    df["REWARD_NT_RN_2"]=df["REWARD_NT_RN_2"].fillna(-1)
    df["HTL_CHAIN_CHN_2"]=df["HTL_CHAIN_CHN_2"].fillna(-1)
    df["HTL_CHAIN_CHN_3"]=df["HTL_CHAIN_CHN_3"].fillna(-1)
    df["HTL_CHAIN_CHN_4"]=df["HTL_CHAIN_CHN_4"].fillna(-1)
    df["HTL_CHAIN_CHN_5"]=df["HTL_CHAIN_CHN_5"].fillna(-1)
    df["HTL_CHAIN_CHN_6"]=df["HTL_CHAIN_CHN_6"].fillna(-1)
    df["HTL_CHAIN_CHN_7"]=df["HTL_CHAIN_CHN_7"].fillna(-1)
    df["HTL_CHAIN_CHN_9"]=df["HTL_CHAIN_CHN_9"].fillna(-1)
    df["HTL_CHAIN_CHN_10"]=df["HTL_CHAIN_CHN_10"].fillna(-1)
    df["HTL_CHAIN_CHN_11"]=df["HTL_CHAIN_CHN_11"].fillna(-1)
    df["HTL_CHAIN_CHN_12"]=df["HTL_CHAIN_CHN_12"].fillna(-1)
    df["HTL_CHAIN_CHN_13"]=df["HTL_CHAIN_CHN_13"].fillna(-1)
    df["HTL_CHAIN_CHN_14"]=df["HTL_CHAIN_CHN_14"].fillna(-1)
    df["HTL_CHAIN_CHN_15"]=df["HTL_CHAIN_CHN_15"].fillna(-1)
    df["HTL_CHAIN_CHN_18"]=df["HTL_CHAIN_CHN_18"].fillna(-1)
    df["HTL_CHAIN_CHN_20"]=df["HTL_CHAIN_CHN_20"].fillna(-1)
    df["HTL_CHAIN_CHN_22"]=df["HTL_CHAIN_CHN_22"].fillna(-1)
    df["HTL_CHAIN_CHN_23"]=df["HTL_CHAIN_CHN_23"].fillna(-1)
    df["NUM_STAYS"]=df["NUM_STAYS"].fillna(0)
    df["TOTAL_STAY_REVENUE"]=df["TOTAL_STAY_REVENUE"].fillna(0)
    df["TOTAL_ROOMS"]=df["TOTAL_ROOMS"].fillna(0)
    df["TOTAL_GUEST_QTY"]=df["TOTAL_GUEST_QTY"].fillna(0)
    df["TOTAL_TIME_BWTN_CONF_CKIN_DT"]=df["TOTAL_TIME_BWTN_CONF_CKIN_DT"].fillna(0)
    df["TOTAL_TIME_BWTN_CKIN_CKOUT_DT"]=df["TOTAL_TIME_BWTN_CKIN_CKOUT_DT"].fillna(0)
    df["TOTAL_CONF_DT_daysto_holiday"]=df["TOTAL_CONF_DT_daysto_holiday"].fillna(0)
    df["TOTAL_CK_IN_DT_daysto_holiday"]=df["TOTAL_CK_IN_DT_daysto_holiday"].fillna(0)
    df["TOTAL_CK_OUT_DT_daysto_holiday"]=df["TOTAL_CK_OUT_DT_daysto_holiday"].fillna(0)
    df["TOTAL_CONF_DT_nearest_holiday_dayofyear"]=df["TOTAL_CONF_DT_nearest_holiday_dayofyear"].fillna(0)
    df["TOTAL_CK_IN_DT_nearest_holiday_dayofyear"]=df["TOTAL_CK_IN_DT_nearest_holiday_dayofyear"].fillna(0)
    df["TOTAL_CK_OUT_DT_nearest_holiday_dayofyear"]=df["TOTAL_CK_OUT_DT_nearest_holiday_dayofyear"].fillna(0)
    df["NUM_BUS_LEIS_IND"]=df["NUM_BUS_LEIS_IND"].fillna(0)
    df["TOTAL_BUS_LEIS_IND_REVENUE"]=df["TOTAL_BUS_LEIS_IND_REVENUE"].fillna(0)
    df["TOTAL_BUS_LEIS_IND_ROOMS"]=df["TOTAL_BUS_LEIS_IND_ROOMS"].fillna(0)
    df["TOTAL_BUS_LEIS_IND_GUEST_QTY"]=df["TOTAL_BUS_LEIS_IND_GUEST_QTY"].fillna(0)
    df["NUM_DIFFERENT_CONTINENT"]=df["NUM_DIFFERENT_CONTINENT"].fillna(0)
    df["TOTAL_DIFFERENT_CONTINENT_REVENUE"]=df["TOTAL_DIFFERENT_CONTINENT_REVENUE"].fillna(0)
    df["TOTAL_DIFFERENT_CONTINENT_ROOMS"]=df["TOTAL_DIFFERENT_CONTINENT_ROOMS"].fillna(0)
    df["TOTAL_DIFFERENT_CONTINENT_GUEST_QTY"]=df["TOTAL_DIFFERENT_CONTINENT_GUEST_QTY"].fillna(0)
    df["NUM_HTL_RGN_EMEAA"]=df["NUM_HTL_RGN_EMEAA"].fillna(0)
    df["TOTAL_HTL_RGN_EMEAA_REVENUE"]=df["TOTAL_HTL_RGN_EMEAA_REVENUE"].fillna(0)
    df["TOTAL_HTL_RGN_EMEAA_ROOMS"]=df["TOTAL_HTL_RGN_EMEAA_ROOMS"].fillna(0)
    df["TOTAL_HTL_RGN_EMEAA_GUEST_QTY"]=df["TOTAL_HTL_RGN_EMEAA_GUEST_QTY"].fillna(0)
    df["NUM_HTL_RGN_GCHINA"]=df["NUM_HTL_RGN_GCHINA"].fillna(0)
    df["TOTAL_HTL_RGN_GCHINA_REVENUE"]=df["TOTAL_HTL_RGN_GCHINA_REVENUE"].fillna(0)
    df["TOTAL_HTL_RGN_GCHINA_ROOMS"]=df["TOTAL_HTL_RGN_GCHINA_ROOMS"].fillna(0)
    df["TOTAL_HTL_RGN_GCHINA_GUEST_QTY"]=df["TOTAL_HTL_RGN_GCHINA_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CATEGORY_CHN_CAT_1"]=df["NUM_HTL_CHAIN_CATEGORY_CHN_CAT_1"].fillna(0)
    df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_REVENUE"]=df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_ROOMS"]=df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CATEGORY_CHN_CAT_2"]=df["NUM_HTL_CHAIN_CATEGORY_CHN_CAT_2"].fillna(0)
    df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_REVENUE"]=df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_ROOMS"]=df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CATEGORY_CHN_CAT_3"]=df["NUM_HTL_CHAIN_CATEGORY_CHN_CAT_3"].fillna(0)
    df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_REVENUE"]=df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_ROOMS"]=df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_GUEST_QTY"].fillna(0)
    df["NUM_REWARD_NT_RN_1"]=df["NUM_REWARD_NT_RN_1"].fillna(0)
    df["TOTAL_REWARD_NT_RN_1_REVENUE"]=df["TOTAL_REWARD_NT_RN_1_REVENUE"].fillna(0)
    df["TOTAL_REWARD_NT_RN_1_ROOMS"]=df["TOTAL_REWARD_NT_RN_1_ROOMS"].fillna(0)
    df["TOTAL_REWARD_NT_RN_1_GUEST_QTY"]=df["TOTAL_REWARD_NT_RN_1_GUEST_QTY"].fillna(0)
    df["NUM_REWARD_NT_RN_2"]=df["NUM_REWARD_NT_RN_2"].fillna(0)
    df["TOTAL_REWARD_NT_RN_2_REVENUE"]=df["TOTAL_REWARD_NT_RN_2_REVENUE"].fillna(0)
    df["TOTAL_REWARD_NT_RN_2_ROOMS"]=df["TOTAL_REWARD_NT_RN_2_ROOMS"].fillna(0)
    df["TOTAL_REWARD_NT_RN_2_GUEST_QTY"]=df["TOTAL_REWARD_NT_RN_2_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_2"]=df["NUM_HTL_CHAIN_CHN_2"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_2_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_2_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_2_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_2_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_2_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_2_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_3"]=df["NUM_HTL_CHAIN_CHN_3"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_3_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_3_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_3_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_3_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_3_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_3_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_4"]=df["NUM_HTL_CHAIN_CHN_4"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_4_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_4_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_4_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_4_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_4_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_4_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_5"]=df["NUM_HTL_CHAIN_CHN_5"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_5_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_5_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_5_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_5_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_5_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_5_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_6"]=df["NUM_HTL_CHAIN_CHN_6"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_6_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_6_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_6_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_6_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_6_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_6_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_7"]=df["NUM_HTL_CHAIN_CHN_7"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_7_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_7_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_7_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_7_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_7_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_7_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_9"]=df["NUM_HTL_CHAIN_CHN_9"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_9_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_9_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_9_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_9_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_9_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_9_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_10"]=df["NUM_HTL_CHAIN_CHN_10"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_10_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_10_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_10_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_10_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_10_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_10_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_11"]=df["NUM_HTL_CHAIN_CHN_11"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_11_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_11_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_11_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_11_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_11_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_11_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_12"]=df["NUM_HTL_CHAIN_CHN_12"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_12_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_12_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_12_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_12_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_12_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_12_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_13"]=df["NUM_HTL_CHAIN_CHN_13"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_13_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_13_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_13_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_13_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_13_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_13_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_14"]=df["NUM_HTL_CHAIN_CHN_14"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_14_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_14_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_14_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_14_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_14_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_14_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_15"]=df["NUM_HTL_CHAIN_CHN_15"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_15_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_15_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_15_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_15_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_15_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_15_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_18"]=df["NUM_HTL_CHAIN_CHN_18"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_18_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_18_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_18_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_18_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_18_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_18_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_20"]=df["NUM_HTL_CHAIN_CHN_20"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_20_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_20_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_20_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_20_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_20_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_20_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_22"]=df["NUM_HTL_CHAIN_CHN_22"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_22_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_22_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_22_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_22_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_22_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_22_GUEST_QTY"].fillna(0)
    df["NUM_HTL_CHAIN_CHN_23"]=df["NUM_HTL_CHAIN_CHN_23"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_23_REVENUE"]=df["TOTAL_HTL_CHAIN_CHN_23_REVENUE"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_23_ROOMS"]=df["TOTAL_HTL_CHAIN_CHN_23_ROOMS"].fillna(0)
    df["TOTAL_HTL_CHAIN_CHN_23_GUEST_QTY"]=df["TOTAL_HTL_CHAIN_CHN_23_GUEST_QTY"].fillna(0)
    return df

# %% [markdown]
# ############################################################################################################################################################################################################################
# ############################################################################################################################################################################################################################

# %% [markdown]
# # Further Feature Engineering

# %%
# %%time

em_proc_dict = {'HASH_NBR': "object", 'CAMPAIGN_NBR': "object", 'UNSUB_IND': "int8", 'SEND_DT': "object", 'CLICK': "int8", 'MBR_PRGM_ACTV': "int8", 'week_of_year': "int8", 'day_of_month': "int8", 'day_of_year': "int8", 'is_end_month': "int8", 'is_start_month': "int8", 'is_end_quarter': "int8", 'is_start_quarter': "int8", 'ENROLL_DT': "object", 'CC_2': "int8", 'CC_3': "int8", 'CC_4': "int8", 'TIER_2': "int8", 'TIER_3': "int8", 'TIER_4': "int8", 'quarter_1': "int8", 'quarter_3': "int8", 'quarter_4': "int8", 'GNDR_1': "int8", 'GNDR_2': "int8", 'EN_1': "int8", 'EN_2': "int8", 'EN_3': "int8", 'EN_4': "int8", 'EN_6': "int8", 'AGE_1': "int8", 'AGE_2': "int8", 'AGE_3': "int8", 'AGE_4': "int8", 'AGE_5': "int8", 'INCOME_1': "int8", 'INCOME_2': "int8", 'INCOME_3': "int8", 'INCOME_4': "int8", 'INCOME_5': "int8", 'January': "int8", 'February': "int8", 'April': "int8", 'May': "int8", 'June': "int8", 'July': "int8", 'August': "int8", 'September': "int8", 'October': "int8", 'November': "int8", 'December': "int8", 'Monday': "int8", 'Tuesday': "int8", 'Wednesday': "int8", 'Thursday': "int8", 'Friday': "int8", 'Saturday': "int8", 'Fall': "int8", 'Summer': "int8", 'Winter': "int8", 'Oceania': "int8", 'Asia_Africa': "int8", 'Europe': "int8", 'AUSTRALASIA_JAPAN': "int8", 'CANADA': "int8", 'CARIBBEAN': "int8", 'EUROPE': "int8", 'HONG_KONG': "int8", 'INDIA_MIDDLE_EAST_AFRICA': "int8", 'LATIN_AMERICA': "int8", 'MAINLAND_CHINA': "int8", 'MEXICO': "int8", 'SOUTHEAST_ASIA_KOREA': "int8", 'TAIWAN': "int8", 'MACAU': "int8"}
stay_dict = {"CONF_HASH_NBR":"object", "HASH_NBR":"object", "BUS_LEIS_IND":"int8", "CONF_DT":"str", "CK_IN_DT":"str", "CK_OUT_DT":"str", "HTL_HASH_NBR":"object", "STAY_REVENUE_USD":"float64", "total_rooms":"int16", "total_GUEST_QTY":"int16", "TIME_BWTN_CONF_CKIN_DT":"int16", "TIME_BWTN_CKIN_CKOUT_DT":"int16", "CONF_DT_daysto_holiday":"int16", "CK_IN_DT_daysto_holiday":"int16", "CK_OUT_DT_daysto_holiday":"int16", "CONF_DT_nearest_holiday_dayofyear":"int16", "CK_IN_DT_nearest_holiday_dayofyear":"int16", "CK_OUT_DT_nearest_holiday_dayofyear":"int16", "DIFFERENT_CONTINENT":"int8", "MBR_TENURE_ASOF_CONF_DT":"int16", "MBR_TENURE_ASOF_CK_IN_DT":"int16", "MBR_TENURE_ASOF_CK_OUT_DT":"int16", "HTL_RGN_EMEAA":"int8", "HTL_RGN_GCHINA":"int8", "HTL_CHAIN_CATEGORY_CHN_CAT_1":"int8", "HTL_CHAIN_CATEGORY_CHN_CAT_2":"int8", "HTL_CHAIN_CATEGORY_CHN_CAT_3":"int8", "REWARD_NT_RN_1":"int8", "REWARD_NT_RN_2":"int8", "HTL_CHAIN_CHN_2":"int8", "HTL_CHAIN_CHN_3":"int8", "HTL_CHAIN_CHN_4":"int8", "HTL_CHAIN_CHN_5":"int8", "HTL_CHAIN_CHN_6":"int8", "HTL_CHAIN_CHN_7":"int8", "HTL_CHAIN_CHN_9":"int8", "HTL_CHAIN_CHN_10":"int8", "HTL_CHAIN_CHN_11":"int8", "HTL_CHAIN_CHN_12":"int8", "HTL_CHAIN_CHN_13":"int8", "HTL_CHAIN_CHN_14":"int8", "HTL_CHAIN_CHN_15":"int8", "HTL_CHAIN_CHN_18":"int8", "HTL_CHAIN_CHN_20":"int8", "HTL_CHAIN_CHN_22":"int8", "HTL_CHAIN_CHN_23":"int8", "NUM_STAYS":"int32", "TOTAL_STAY_REVENUE":"float64", "TOTAL_ROOMS":"int32", "TOTAL_GUEST_QTY":"int32", "TOTAL_TIME_BWTN_CONF_CKIN_DT":"int32", "TOTAL_TIME_BWTN_CKIN_CKOUT_DT":"int32", "TOTAL_CONF_DT_daysto_holiday":"int32", "TOTAL_CK_IN_DT_daysto_holiday":"int32", "TOTAL_CK_OUT_DT_daysto_holiday":"int32", "TOTAL_CONF_DT_nearest_holiday_dayofyear":"int32", "TOTAL_CK_IN_DT_nearest_holiday_dayofyear":"int32", "TOTAL_CK_OUT_DT_nearest_holiday_dayofyear":"int32", "NUM_BUS_LEIS_IND":"int32", "TOTAL_BUS_LEIS_IND_REVENUE":"float64", "TOTAL_BUS_LEIS_IND_ROOMS":"int32", "TOTAL_BUS_LEIS_IND_GUEST_QTY":"int32", "NUM_DIFFERENT_CONTINENT":"int32", "TOTAL_DIFFERENT_CONTINENT_REVENUE":"float64", "TOTAL_DIFFERENT_CONTINENT_ROOMS":"int32", "TOTAL_DIFFERENT_CONTINENT_GUEST_QTY":"int32", "NUM_HTL_RGN_EMEAA":"int32", "TOTAL_HTL_RGN_EMEAA_REVENUE":"float64", "TOTAL_HTL_RGN_EMEAA_ROOMS":"int32", "TOTAL_HTL_RGN_EMEAA_GUEST_QTY":"int32", "NUM_HTL_RGN_GCHINA":"int32", "TOTAL_HTL_RGN_GCHINA_REVENUE":"float64", "TOTAL_HTL_RGN_GCHINA_ROOMS":"int32", "TOTAL_HTL_RGN_GCHINA_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CATEGORY_CHN_CAT_1":"int32", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_REVENUE":"float64", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_ROOMS":"int32", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CATEGORY_CHN_CAT_2":"int32", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_REVENUE":"float64", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_ROOMS":"int32", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CATEGORY_CHN_CAT_3":"int32", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_REVENUE":"float64", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_ROOMS":"int32", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_GUEST_QTY":"int32", "NUM_REWARD_NT_RN_1":"int32", "TOTAL_REWARD_NT_RN_1_REVENUE":"float64", "TOTAL_REWARD_NT_RN_1_ROOMS":"int32", "TOTAL_REWARD_NT_RN_1_GUEST_QTY":"int32", "NUM_REWARD_NT_RN_2":"int32", "TOTAL_REWARD_NT_RN_2_REVENUE":"float64", "TOTAL_REWARD_NT_RN_2_ROOMS":"int32", "TOTAL_REWARD_NT_RN_2_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_2":"int32", "TOTAL_HTL_CHAIN_CHN_2_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_2_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_2_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_3":"int32", "TOTAL_HTL_CHAIN_CHN_3_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_3_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_3_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_4":"int32", "TOTAL_HTL_CHAIN_CHN_4_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_4_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_4_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_5":"int32", "TOTAL_HTL_CHAIN_CHN_5_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_5_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_5_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_6":"int32", "TOTAL_HTL_CHAIN_CHN_6_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_6_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_6_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_7":"int32", "TOTAL_HTL_CHAIN_CHN_7_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_7_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_7_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_9":"int32", "TOTAL_HTL_CHAIN_CHN_9_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_9_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_9_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_10":"int32", "TOTAL_HTL_CHAIN_CHN_10_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_10_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_10_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_11":"int32", "TOTAL_HTL_CHAIN_CHN_11_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_11_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_11_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_12":"int32", "TOTAL_HTL_CHAIN_CHN_12_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_12_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_12_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_13":"int32", "TOTAL_HTL_CHAIN_CHN_13_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_13_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_13_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_14":"int32", "TOTAL_HTL_CHAIN_CHN_14_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_14_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_14_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_15":"int32", "TOTAL_HTL_CHAIN_CHN_15_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_15_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_15_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_18":"int32", "TOTAL_HTL_CHAIN_CHN_18_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_18_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_18_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_20":"int32", "TOTAL_HTL_CHAIN_CHN_20_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_20_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_20_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_22":"int32", "TOTAL_HTL_CHAIN_CHN_22_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_22_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_22_GUEST_QTY":"int32", "NUM_HTL_CHAIN_CHN_23":"int32", "TOTAL_HTL_CHAIN_CHN_23_REVENUE":"float64", "TOTAL_HTL_CHAIN_CHN_23_ROOMS":"int32", "TOTAL_HTL_CHAIN_CHN_23_GUEST_QTY":"int32"}
partial_dict = {'HASH_NBR': "object", "CONF_HASH_NBR":"object", "HTL_HASH_NBR":"object", "CONF_DT": "str", "CK_IN_DT": "str", "CK_OUT_DT": "str", "SEND_DT": "str", "NUM_UNIQUE_CONF_HASH_NBR": "int32", "NUM_UNIQUE_HTL_HASH_NBR": "int32"}

stay_df = pd.read_csv(stay_hist_pth_process2, dtype = stay_dict, parse_dates = ["CONF_DT", "CK_IN_DT", "CK_OUT_DT"])

nr = 1000000

chunk_zip = zip(pd.read_csv(email_hist_pth_process, chunksize = nr, dtype = em_proc_dict, parse_dates = ["SEND_DT", "ENROLL_DT"]),
                pd.read_csv(email_hist_pth_process2, chunksize = nr, dtype = partial_dict, parse_dates = ["SEND_DT", "CONF_DT", "CK_IN_DT", "CK_OUT_DT"]))

n = 0
for i, df_tup in enumerate(chunk_zip):
    
    merge_df = pd.merge(left = df_tup[1].reset_index(drop = True),
                        right = stay_df,
                        left_on = ["HASH_NBR", "HTL_HASH_NBR", "CONF_HASH_NBR", "CONF_DT", "CK_IN_DT", "CK_OUT_DT"],
                        right_on = ["HASH_NBR", "HTL_HASH_NBR", "CONF_HASH_NBR", "CONF_DT", "CK_IN_DT", "CK_OUT_DT"],
                        how = "left")

    merge_df = df_fillna(merge_df)

    merge_df = pd.merge(left = df_tup[0].reset_index(drop = True),
                        right = merge_df,
                        left_on = ["HASH_NBR", "SEND_DT"],
                        right_on = ["HASH_NBR", "SEND_DT"],
                        how = "left")

    merge_df["MBR_TENURE"] = (merge_df["SEND_DT"] - merge_df["ENROLL_DT"]).dt.days
    merge_df.loc[merge_df["MBR_TENURE_ASOF_CONF_DT"].isna(), "MBR_TENURE_ASOF_CONF_DT"] = (merge_df["CONF_DT"] - merge_df["ENROLL_DT"]).dt.days
    merge_df.loc[merge_df["MBR_TENURE_ASOF_CK_IN_DT"].isna(), "MBR_TENURE_ASOF_CK_IN_DT"] = (merge_df["CK_IN_DT"] - merge_df["ENROLL_DT"]).dt.days
    merge_df.loc[merge_df["MBR_TENURE_ASOF_CK_OUT_DT"].isna(), "MBR_TENURE_ASOF_CK_OUT_DT"] = (merge_df["CK_OUT_DT"] - merge_df["ENROLL_DT"]).dt.days

    merge_df = merge_df.astype(stay_dict)
    merge_df.drop(["ENROLL_DT", "CONF_DT", "CK_IN_DT", "CK_OUT_DT"], axis = 1, inplace = True)
    
    merge_df.drop_duplicates(inplace = True)

    if i == 0:
        merge_df.to_csv(email_hist_pth_process3, index = False, mode = 'w')
    else:
        merge_df.to_csv(email_hist_pth_process3, index = False, mode = 'a', header = False)
    
    n = n + merge_df.shape[0]
    print("#################################################")
    print(f"Chunk {i} Completed -- {datetime.datetime.now()}")
    print(f"ROWS PROCESSED: {n}")
    print("#################################################")
# Out:
# #################################################
# Chunk 0 Completed -- 2023-04-08 19:59:27.531815
# ROWS PROCESSED: 1000004
# #################################################
# #################################################
# Chunk 1 Completed -- 2023-04-08 20:01:35.707866
# ROWS PROCESSED: 2000010
# #################################################
# #################################################
# Chunk 2 Completed -- 2023-04-08 20:03:39.108448
# ROWS PROCESSED: 3000019
# #################################################
# #################################################
# Chunk 3 Completed -- 2023-04-08 20:05:48.083828
# ROWS PROCESSED: 4000030
# #################################################
# #################################################
# Chunk 4 Completed -- 2023-04-08 20:07:51.002266
# ROWS PROCESSED: 5000037
# #################################################
# #################################################
# ...

# %%
# %%time

nr = 500000
n = 0
full_email = {"HASH_NBR": "object", "CAMPAIGN_NBR": "object", "UNSUB_IND": "int8", "SEND_DT": "object", "CLICK": "int8", "MBR_PRGM_ACTV": "int8", "week_of_year": "int16", "day_of_month": "int16", "day_of_year": "int16", "is_end_month": "int8", "is_start_month": "int8", "is_end_quarter": "int8", "is_start_quarter": "int8", "CC_2": "int8", "CC_3": "int8", "CC_4": "int8", "TIER_2": "int8", "TIER_3": "int8", "TIER_4": "int8", "quarter_1": "int8", "quarter_3": "int8", "quarter_4": "int8", "GNDR_1": "int8", "GNDR_2": "int8", "EN_1": "int8", "EN_2": "int8", "EN_3": "int8", "EN_4": "int8", "EN_6": "int8", "AGE_1": "int8", "AGE_2": "int8", "AGE_3": "int8", "AGE_4": "int8", "AGE_5": "int8", "INCOME_1": "int8", "INCOME_2": "int8", "INCOME_3": "int8", "INCOME_4": "int8", "INCOME_5": "int8", "January": "int8", "February": "int8", "April": "int8", "May": "int8", "June": "int8", "July": "int8", "August": "int8", "September": "int8", "October": "int8", "November": "int8", "December": "int8", "Monday": "int8", "Tuesday": "int8", "Wednesday": "int8", "Thursday": "int8", "Friday": "int8", "Saturday": "int8", "Fall": "int8", "Summer": "int8", "Winter": "int8", "Oceania": "int8", "Asia_Africa": "int8", "Europe": "int8", "AUSTRALASIA_JAPAN": "int8", "CANADA": "int8", "CARIBBEAN": "int8", "EUROPE": "int8", "HONG_KONG": "int8", "INDIA_MIDDLE_EAST_AFRICA": "int8", "LATIN_AMERICA": "int8", "MAINLAND_CHINA": "int8", "MEXICO": "int8", "SOUTHEAST_ASIA_KOREA": "int8", "TAIWAN": "int8", "MACAU": "int8", "CONF_HASH_NBR": "int64", "HTL_HASH_NBR": "int64", "NUM_UNIQUE_CONF_HASH_NBR": "int16", "NUM_UNIQUE_HTL_HASH_NBR": "int16", "BUS_LEIS_IND": "int8", "STAY_REVENUE_USD": "float64", "total_rooms": "int16", "total_GUEST_QTY": "int16", "TIME_BWTN_CONF_CKIN_DT": "int16", "TIME_BWTN_CKIN_CKOUT_DT": "int16", "CONF_DT_daysto_holiday": "int16", "CK_IN_DT_daysto_holiday": "int16", "CK_OUT_DT_daysto_holiday": "int16", "CONF_DT_nearest_holiday_dayofyear": "int16", "CK_IN_DT_nearest_holiday_dayofyear": "int16", "CK_OUT_DT_nearest_holiday_dayofyear": "int16", "DIFFERENT_CONTINENT": "int8", "MBR_TENURE_ASOF_CONF_DT": "int16", "MBR_TENURE_ASOF_CK_IN_DT": "int16", "MBR_TENURE_ASOF_CK_OUT_DT": "int16", "HTL_RGN_EMEAA": "int8", "HTL_RGN_GCHINA": "int8", "HTL_CHAIN_CATEGORY_CHN_CAT_1": "int8", "HTL_CHAIN_CATEGORY_CHN_CAT_2": "int8", "HTL_CHAIN_CATEGORY_CHN_CAT_3": "int8", "REWARD_NT_RN_1": "int8", "REWARD_NT_RN_2": "int8", "HTL_CHAIN_CHN_2": "int8", "HTL_CHAIN_CHN_3": "int8", "HTL_CHAIN_CHN_4": "int8", "HTL_CHAIN_CHN_5": "int8", "HTL_CHAIN_CHN_6": "int8", "HTL_CHAIN_CHN_7": "int8", "HTL_CHAIN_CHN_9": "int8", "HTL_CHAIN_CHN_10": "int8", "HTL_CHAIN_CHN_11": "int8", "HTL_CHAIN_CHN_12": "int8", "HTL_CHAIN_CHN_13": "int8", "HTL_CHAIN_CHN_14": "int8", "HTL_CHAIN_CHN_15": "int8", "HTL_CHAIN_CHN_18": "int8", "HTL_CHAIN_CHN_20": "int8", "HTL_CHAIN_CHN_22": "int8", "HTL_CHAIN_CHN_23": "int8", "NUM_STAYS": "int16", "TOTAL_STAY_REVENUE": "float64", "TOTAL_ROOMS": "int16", "TOTAL_GUEST_QTY": "int16", "TOTAL_TIME_BWTN_CONF_CKIN_DT": "int16", "TOTAL_TIME_BWTN_CKIN_CKOUT_DT": "int16", "TOTAL_CONF_DT_daysto_holiday": "int16", "TOTAL_CK_IN_DT_daysto_holiday": "int16", "TOTAL_CK_OUT_DT_daysto_holiday": "int16", "TOTAL_CONF_DT_nearest_holiday_dayofyear": "int16", "TOTAL_CK_IN_DT_nearest_holiday_dayofyear": "int16", "TOTAL_CK_OUT_DT_nearest_holiday_dayofyear": "int16", "NUM_BUS_LEIS_IND": "int16", "TOTAL_BUS_LEIS_IND_REVENUE": "float64", "TOTAL_BUS_LEIS_IND_ROOMS": "int16", "TOTAL_BUS_LEIS_IND_GUEST_QTY": "int16", "NUM_DIFFERENT_CONTINENT": "int16", "TOTAL_DIFFERENT_CONTINENT_REVENUE": "float64", "TOTAL_DIFFERENT_CONTINENT_ROOMS": "int16", "TOTAL_DIFFERENT_CONTINENT_GUEST_QTY": "int16", "NUM_HTL_RGN_EMEAA": "int16", "TOTAL_HTL_RGN_EMEAA_REVENUE": "float64", "TOTAL_HTL_RGN_EMEAA_ROOMS": "int16", "TOTAL_HTL_RGN_EMEAA_GUEST_QTY": "int16", "NUM_HTL_RGN_GCHINA": "int16", "TOTAL_HTL_RGN_GCHINA_REVENUE": "float64", "TOTAL_HTL_RGN_GCHINA_ROOMS": "int16", "TOTAL_HTL_RGN_GCHINA_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CATEGORY_CHN_CAT_1": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_REVENUE": "float64", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_ROOMS": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CATEGORY_CHN_CAT_2": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_REVENUE": "float64", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_ROOMS": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CATEGORY_CHN_CAT_3": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_REVENUE": "float64", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_ROOMS": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_GUEST_QTY": "int16", "NUM_REWARD_NT_RN_1": "int16", "TOTAL_REWARD_NT_RN_1_REVENUE": "float64", "TOTAL_REWARD_NT_RN_1_ROOMS": "int16", "TOTAL_REWARD_NT_RN_1_GUEST_QTY": "int16", "NUM_REWARD_NT_RN_2": "int16", "TOTAL_REWARD_NT_RN_2_REVENUE": "float64", "TOTAL_REWARD_NT_RN_2_ROOMS": "int16", "TOTAL_REWARD_NT_RN_2_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_2": "int16", "TOTAL_HTL_CHAIN_CHN_2_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_2_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_2_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_3": "int16", "TOTAL_HTL_CHAIN_CHN_3_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_3_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_3_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_4": "int16", "TOTAL_HTL_CHAIN_CHN_4_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_4_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_4_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_5": "int16", "TOTAL_HTL_CHAIN_CHN_5_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_5_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_5_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_6": "int16", "TOTAL_HTL_CHAIN_CHN_6_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_6_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_6_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_7": "int16", "TOTAL_HTL_CHAIN_CHN_7_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_7_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_7_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_9": "int16", "TOTAL_HTL_CHAIN_CHN_9_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_9_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_9_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_10": "int16", "TOTAL_HTL_CHAIN_CHN_10_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_10_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_10_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_11": "int16", "TOTAL_HTL_CHAIN_CHN_11_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_11_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_11_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_12": "int16", "TOTAL_HTL_CHAIN_CHN_12_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_12_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_12_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_13": "int16", "TOTAL_HTL_CHAIN_CHN_13_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_13_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_13_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_14": "int16", "TOTAL_HTL_CHAIN_CHN_14_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_14_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_14_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_15": "int16", "TOTAL_HTL_CHAIN_CHN_15_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_15_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_15_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_18": "int16", "TOTAL_HTL_CHAIN_CHN_18_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_18_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_18_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_20": "int16", "TOTAL_HTL_CHAIN_CHN_20_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_20_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_20_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_22": "int16", "TOTAL_HTL_CHAIN_CHN_22_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_22_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_22_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_23": "int16", "TOTAL_HTL_CHAIN_CHN_23_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_23_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_23_GUEST_QTY": "int16", "MBR_TENURE": "int16"}
for i, full_email_df in enumerate(pd.read_csv(email_hist_pth_process3, chunksize = nr, dtype = full_email, parse_dates = ["SEND_DT"])):

    print("#################################################")
    print(f"Chunk {i} Started -- {datetime.datetime.now()}")
    
    if i > (169030939 / nr):
        full_email_df.drop(["Europe", "total_rooms", "total_GUEST_QTY"], axis = 1, inplace = True)
        full_email_df.reset_index(drop = True, inplace = True)

#         full_email_df = pd.merge(left = full_email_df,
#                                  right = df[((df["HASH_NBR"].isin(full_email_df["HASH_NBR"].values)) & df["CAMPAIGN_NBR"].isin(full_email_df["CAMPAIGN_NBR"].values) & df["SEND_DT"].isin(full_email_df["SEND_DT"].values))].reset_index(drop = True),
#                                  left_on = ["HASH_NBR", "CAMPAIGN_NBR", "SEND_DT", "CLICK"],
#                                  right_on = ["HASH_NBR", "CAMPAIGN_NBR", "SEND_DT", "CLICK"],
#                                  how = "left"
#                                 )

        full_email_df.to_csv(temp_pth, index = False, mode = 'a', header = False)

    
        
    n = n + full_email_df.shape[0]
    print(f"Chunk {i} Completed -- {datetime.datetime.now()}")
    print(f"ROWS PROCESSED: {n}")
    print("#################################################")
# Out:
# #################################################
# Chunk 0 Started -- 2023-04-11 06:43:36.093187
# Chunk 0 Completed -- 2023-04-11 06:43:36.093238
# ROWS PROCESSED: 500000
# #################################################
# #################################################
# Chunk 1 Started -- 2023-04-11 06:43:42.706391
# Chunk 1 Completed -- 2023-04-11 06:43:42.706440
# ROWS PROCESSED: 1000000
# #################################################
# #################################################
# Chunk 2 Started -- 2023-04-11 06:43:49.325764
# Chunk 2 Completed -- 2023-04-11 06:43:49.325813
# ROWS PROCESSED: 1500000
# #################################################
# #################################################
# Chunk 3 Started -- 2023-04-11 06:43:56.064547
# Chunk 3 Completed -- 2023-04-11 06:43:56.064598
# ROWS PROCESSED: 2000000
# #################################################
# #################################################
# ...

# %%
# %%time

col_list = ['HASH_NBR', 'CAMPAIGN_NBR', 'UNSUB_IND', 'SEND_DT', 'CLICK', 'MBR_PRGM_ACTV', 'week_of_year', 'day_of_month', 'day_of_year', 'is_end_month', 'is_start_month', 'is_end_quarter', 'is_start_quarter', 'CC_2', 'CC_3', 'CC_4', 'TIER_2', 'TIER_3', 'TIER_4', 'quarter_1', 'quarter_3', 'quarter_4', 'GNDR_1', 'GNDR_2', 'EN_1', 'EN_2', 'EN_3', 'EN_4', 'EN_6', 'AGE_1', 'AGE_2', 'AGE_3', 'AGE_4', 'AGE_5', 'INCOME_1', 'INCOME_2', 'INCOME_3', 'INCOME_4', 'INCOME_5', 'January', 'February', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Fall', 'Summer', 'Winter', 'Oceania', 'Asia_Africa', 'AUSTRALASIA_JAPAN', 'CANADA', 'CARIBBEAN', 'EUROPE', 'HONG_KONG', 'INDIA_MIDDLE_EAST_AFRICA', 'LATIN_AMERICA', 'MAINLAND_CHINA', 'MEXICO', 'SOUTHEAST_ASIA_KOREA', 'TAIWAN', 'MACAU', 'CONF_HASH_NBR', 'HTL_HASH_NBR', 'NUM_UNIQUE_CONF_HASH_NBR', 'NUM_UNIQUE_HTL_HASH_NBR', 'BUS_LEIS_IND', 'STAY_REVENUE_USD', 'TIME_BWTN_CONF_CKIN_DT', 'TIME_BWTN_CKIN_CKOUT_DT', 'CONF_DT_daysto_holiday', 'CK_IN_DT_daysto_holiday', 'CK_OUT_DT_daysto_holiday', 'CONF_DT_nearest_holiday_dayofyear', 'CK_IN_DT_nearest_holiday_dayofyear', 'CK_OUT_DT_nearest_holiday_dayofyear', 'DIFFERENT_CONTINENT', 'MBR_TENURE_ASOF_CONF_DT', 'MBR_TENURE_ASOF_CK_IN_DT', 'MBR_TENURE_ASOF_CK_OUT_DT', 'HTL_RGN_EMEAA', 'HTL_RGN_GCHINA', 'HTL_CHAIN_CATEGORY_CHN_CAT_1', 'HTL_CHAIN_CATEGORY_CHN_CAT_2', 'HTL_CHAIN_CATEGORY_CHN_CAT_3', 'REWARD_NT_RN_1', 'REWARD_NT_RN_2', 'HTL_CHAIN_CHN_2', 'HTL_CHAIN_CHN_3', 'HTL_CHAIN_CHN_4', 'HTL_CHAIN_CHN_5', 'HTL_CHAIN_CHN_6', 'HTL_CHAIN_CHN_7', 'HTL_CHAIN_CHN_9', 'HTL_CHAIN_CHN_10', 'HTL_CHAIN_CHN_11', 'HTL_CHAIN_CHN_12', 'HTL_CHAIN_CHN_13', 'HTL_CHAIN_CHN_14', 'HTL_CHAIN_CHN_15', 'HTL_CHAIN_CHN_18', 'HTL_CHAIN_CHN_20', 'HTL_CHAIN_CHN_22', 'HTL_CHAIN_CHN_23', 'NUM_STAYS', 'TOTAL_STAY_REVENUE', 'TOTAL_ROOMS', 'TOTAL_GUEST_QTY', 'TOTAL_TIME_BWTN_CONF_CKIN_DT', 'TOTAL_TIME_BWTN_CKIN_CKOUT_DT', 'TOTAL_CONF_DT_daysto_holiday', 'TOTAL_CK_IN_DT_daysto_holiday', 'TOTAL_CK_OUT_DT_daysto_holiday', 'TOTAL_CONF_DT_nearest_holiday_dayofyear', 'TOTAL_CK_IN_DT_nearest_holiday_dayofyear', 'TOTAL_CK_OUT_DT_nearest_holiday_dayofyear', 'NUM_BUS_LEIS_IND', 'TOTAL_BUS_LEIS_IND_REVENUE', 'TOTAL_BUS_LEIS_IND_ROOMS', 'TOTAL_BUS_LEIS_IND_GUEST_QTY', 'NUM_DIFFERENT_CONTINENT', 'TOTAL_DIFFERENT_CONTINENT_REVENUE', 'TOTAL_DIFFERENT_CONTINENT_ROOMS', 'TOTAL_DIFFERENT_CONTINENT_GUEST_QTY', 'NUM_HTL_RGN_EMEAA', 'TOTAL_HTL_RGN_EMEAA_REVENUE', 'TOTAL_HTL_RGN_EMEAA_ROOMS', 'TOTAL_HTL_RGN_EMEAA_GUEST_QTY', 'NUM_HTL_RGN_GCHINA', 'TOTAL_HTL_RGN_GCHINA_REVENUE', 'TOTAL_HTL_RGN_GCHINA_ROOMS', 'TOTAL_HTL_RGN_GCHINA_GUEST_QTY', 'NUM_HTL_CHAIN_CATEGORY_CHN_CAT_1', 'TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_REVENUE', 'TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_ROOMS', 'TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_GUEST_QTY', 'NUM_HTL_CHAIN_CATEGORY_CHN_CAT_2', 'TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_REVENUE', 'TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_ROOMS', 'TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_GUEST_QTY', 'NUM_HTL_CHAIN_CATEGORY_CHN_CAT_3', 'TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_REVENUE', 'TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_ROOMS', 'TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_GUEST_QTY', 'NUM_REWARD_NT_RN_1', 'TOTAL_REWARD_NT_RN_1_REVENUE', 'TOTAL_REWARD_NT_RN_1_ROOMS', 'TOTAL_REWARD_NT_RN_1_GUEST_QTY', 'NUM_REWARD_NT_RN_2', 'TOTAL_REWARD_NT_RN_2_REVENUE', 'TOTAL_REWARD_NT_RN_2_ROOMS', 'TOTAL_REWARD_NT_RN_2_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_2', 'TOTAL_HTL_CHAIN_CHN_2_REVENUE', 'TOTAL_HTL_CHAIN_CHN_2_ROOMS', 'TOTAL_HTL_CHAIN_CHN_2_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_3', 'TOTAL_HTL_CHAIN_CHN_3_REVENUE', 'TOTAL_HTL_CHAIN_CHN_3_ROOMS', 'TOTAL_HTL_CHAIN_CHN_3_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_4', 'TOTAL_HTL_CHAIN_CHN_4_REVENUE', 'TOTAL_HTL_CHAIN_CHN_4_ROOMS', 'TOTAL_HTL_CHAIN_CHN_4_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_5', 'TOTAL_HTL_CHAIN_CHN_5_REVENUE', 'TOTAL_HTL_CHAIN_CHN_5_ROOMS', 'TOTAL_HTL_CHAIN_CHN_5_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_6', 'TOTAL_HTL_CHAIN_CHN_6_REVENUE', 'TOTAL_HTL_CHAIN_CHN_6_ROOMS', 'TOTAL_HTL_CHAIN_CHN_6_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_7', 'TOTAL_HTL_CHAIN_CHN_7_REVENUE', 'TOTAL_HTL_CHAIN_CHN_7_ROOMS', 'TOTAL_HTL_CHAIN_CHN_7_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_9', 'TOTAL_HTL_CHAIN_CHN_9_REVENUE', 'TOTAL_HTL_CHAIN_CHN_9_ROOMS', 'TOTAL_HTL_CHAIN_CHN_9_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_10', 'TOTAL_HTL_CHAIN_CHN_10_REVENUE', 'TOTAL_HTL_CHAIN_CHN_10_ROOMS', 'TOTAL_HTL_CHAIN_CHN_10_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_11', 'TOTAL_HTL_CHAIN_CHN_11_REVENUE', 'TOTAL_HTL_CHAIN_CHN_11_ROOMS', 'TOTAL_HTL_CHAIN_CHN_11_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_12', 'TOTAL_HTL_CHAIN_CHN_12_REVENUE', 'TOTAL_HTL_CHAIN_CHN_12_ROOMS', 'TOTAL_HTL_CHAIN_CHN_12_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_13', 'TOTAL_HTL_CHAIN_CHN_13_REVENUE', 'TOTAL_HTL_CHAIN_CHN_13_ROOMS', 'TOTAL_HTL_CHAIN_CHN_13_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_14', 'TOTAL_HTL_CHAIN_CHN_14_REVENUE', 'TOTAL_HTL_CHAIN_CHN_14_ROOMS', 'TOTAL_HTL_CHAIN_CHN_14_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_15', 'TOTAL_HTL_CHAIN_CHN_15_REVENUE', 'TOTAL_HTL_CHAIN_CHN_15_ROOMS', 'TOTAL_HTL_CHAIN_CHN_15_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_18', 'TOTAL_HTL_CHAIN_CHN_18_REVENUE', 'TOTAL_HTL_CHAIN_CHN_18_ROOMS', 'TOTAL_HTL_CHAIN_CHN_18_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_20', 'TOTAL_HTL_CHAIN_CHN_20_REVENUE', 'TOTAL_HTL_CHAIN_CHN_20_ROOMS', 'TOTAL_HTL_CHAIN_CHN_20_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_22', 'TOTAL_HTL_CHAIN_CHN_22_REVENUE', 'TOTAL_HTL_CHAIN_CHN_22_ROOMS', 'TOTAL_HTL_CHAIN_CHN_22_GUEST_QTY', 'NUM_HTL_CHAIN_CHN_23', 'TOTAL_HTL_CHAIN_CHN_23_REVENUE', 'TOTAL_HTL_CHAIN_CHN_23_ROOMS', 'TOTAL_HTL_CHAIN_CHN_23_GUEST_QTY', 'MBR_TENURE']
full_email = {"HASH_NBR": "object", "CAMPAIGN_NBR": "object", "UNSUB_IND": "int8", "SEND_DT": "object", "CLICK": "int8", "MBR_PRGM_ACTV": "int8", "week_of_year": "int16", "day_of_month": "int16", "day_of_year": "int16", "is_end_month": "int8", "is_start_month": "int8", "is_end_quarter": "int8", "is_start_quarter": "int8", "CC_2": "int8", "CC_3": "int8", "CC_4": "int8", "TIER_2": "int8", "TIER_3": "int8", "TIER_4": "int8", "quarter_1": "int8", "quarter_3": "int8", "quarter_4": "int8", "GNDR_1": "int8", "GNDR_2": "int8", "EN_1": "int8", "EN_2": "int8", "EN_3": "int8", "EN_4": "int8", "EN_6": "int8", "AGE_1": "int8", "AGE_2": "int8", "AGE_3": "int8", "AGE_4": "int8", "AGE_5": "int8", "INCOME_1": "int8", "INCOME_2": "int8", "INCOME_3": "int8", "INCOME_4": "int8", "INCOME_5": "int8", "January": "int8", "February": "int8", "April": "int8", "May": "int8", "June": "int8", "July": "int8", "August": "int8", "September": "int8", "October": "int8", "November": "int8", "December": "int8", "Monday": "int8", "Tuesday": "int8", "Wednesday": "int8", "Thursday": "int8", "Friday": "int8", "Saturday": "int8", "Fall": "int8", "Summer": "int8", "Winter": "int8", "Oceania": "int8", "Asia_Africa": "int8", "AUSTRALASIA_JAPAN": "int8", "CANADA": "int8", "CARIBBEAN": "int8", "EUROPE": "int8", "HONG_KONG": "int8", "INDIA_MIDDLE_EAST_AFRICA": "int8", "LATIN_AMERICA": "int8", "MAINLAND_CHINA": "int8", "MEXICO": "int8", "SOUTHEAST_ASIA_KOREA": "int8", "TAIWAN": "int8", "MACAU": "int8", "CONF_HASH_NBR": "int64", "HTL_HASH_NBR": "int64", "NUM_UNIQUE_CONF_HASH_NBR": "int16", "NUM_UNIQUE_HTL_HASH_NBR": "int16", "BUS_LEIS_IND": "int8", "STAY_REVENUE_USD": "float64", "TIME_BWTN_CONF_CKIN_DT": "int16", "TIME_BWTN_CKIN_CKOUT_DT": "int16", "CONF_DT_daysto_holiday": "int16", "CK_IN_DT_daysto_holiday": "int16", "CK_OUT_DT_daysto_holiday": "int16", "CONF_DT_nearest_holiday_dayofyear": "int16", "CK_IN_DT_nearest_holiday_dayofyear": "int16", "CK_OUT_DT_nearest_holiday_dayofyear": "int16", "DIFFERENT_CONTINENT": "int8", "MBR_TENURE_ASOF_CONF_DT": "int16", "MBR_TENURE_ASOF_CK_IN_DT": "int16", "MBR_TENURE_ASOF_CK_OUT_DT": "int16", "HTL_RGN_EMEAA": "int8", "HTL_RGN_GCHINA": "int8", "HTL_CHAIN_CATEGORY_CHN_CAT_1": "int8", "HTL_CHAIN_CATEGORY_CHN_CAT_2": "int8", "HTL_CHAIN_CATEGORY_CHN_CAT_3": "int8", "REWARD_NT_RN_1": "int8", "REWARD_NT_RN_2": "int8", "HTL_CHAIN_CHN_2": "int8", "HTL_CHAIN_CHN_3": "int8", "HTL_CHAIN_CHN_4": "int8", "HTL_CHAIN_CHN_5": "int8", "HTL_CHAIN_CHN_6": "int8", "HTL_CHAIN_CHN_7": "int8", "HTL_CHAIN_CHN_9": "int8", "HTL_CHAIN_CHN_10": "int8", "HTL_CHAIN_CHN_11": "int8", "HTL_CHAIN_CHN_12": "int8", "HTL_CHAIN_CHN_13": "int8", "HTL_CHAIN_CHN_14": "int8", "HTL_CHAIN_CHN_15": "int8", "HTL_CHAIN_CHN_18": "int8", "HTL_CHAIN_CHN_20": "int8", "HTL_CHAIN_CHN_22": "int8", "HTL_CHAIN_CHN_23": "int8", "NUM_STAYS": "int16", "TOTAL_STAY_REVENUE": "float64", "TOTAL_ROOMS": "int16", "TOTAL_GUEST_QTY": "int16", "TOTAL_TIME_BWTN_CONF_CKIN_DT": "int16", "TOTAL_TIME_BWTN_CKIN_CKOUT_DT": "int16", "TOTAL_CONF_DT_daysto_holiday": "int16", "TOTAL_CK_IN_DT_daysto_holiday": "int16", "TOTAL_CK_OUT_DT_daysto_holiday": "int16", "TOTAL_CONF_DT_nearest_holiday_dayofyear": "int16", "TOTAL_CK_IN_DT_nearest_holiday_dayofyear": "int16", "TOTAL_CK_OUT_DT_nearest_holiday_dayofyear": "int16", "NUM_BUS_LEIS_IND": "int16", "TOTAL_BUS_LEIS_IND_REVENUE": "float64", "TOTAL_BUS_LEIS_IND_ROOMS": "int16", "TOTAL_BUS_LEIS_IND_GUEST_QTY": "int16", "NUM_DIFFERENT_CONTINENT": "int16", "TOTAL_DIFFERENT_CONTINENT_REVENUE": "float64", "TOTAL_DIFFERENT_CONTINENT_ROOMS": "int16", "TOTAL_DIFFERENT_CONTINENT_GUEST_QTY": "int16", "NUM_HTL_RGN_EMEAA": "int16", "TOTAL_HTL_RGN_EMEAA_REVENUE": "float64", "TOTAL_HTL_RGN_EMEAA_ROOMS": "int16", "TOTAL_HTL_RGN_EMEAA_GUEST_QTY": "int16", "NUM_HTL_RGN_GCHINA": "int16", "TOTAL_HTL_RGN_GCHINA_REVENUE": "float64", "TOTAL_HTL_RGN_GCHINA_ROOMS": "int16", "TOTAL_HTL_RGN_GCHINA_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CATEGORY_CHN_CAT_1": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_REVENUE": "float64", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_ROOMS": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CATEGORY_CHN_CAT_2": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_REVENUE": "float64", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_ROOMS": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CATEGORY_CHN_CAT_3": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_REVENUE": "float64", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_ROOMS": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_GUEST_QTY": "int16", "NUM_REWARD_NT_RN_1": "int16", "TOTAL_REWARD_NT_RN_1_REVENUE": "float64", "TOTAL_REWARD_NT_RN_1_ROOMS": "int16", "TOTAL_REWARD_NT_RN_1_GUEST_QTY": "int16", "NUM_REWARD_NT_RN_2": "int16", "TOTAL_REWARD_NT_RN_2_REVENUE": "float64", "TOTAL_REWARD_NT_RN_2_ROOMS": "int16", "TOTAL_REWARD_NT_RN_2_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_2": "int16", "TOTAL_HTL_CHAIN_CHN_2_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_2_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_2_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_3": "int16", "TOTAL_HTL_CHAIN_CHN_3_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_3_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_3_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_4": "int16", "TOTAL_HTL_CHAIN_CHN_4_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_4_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_4_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_5": "int16", "TOTAL_HTL_CHAIN_CHN_5_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_5_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_5_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_6": "int16", "TOTAL_HTL_CHAIN_CHN_6_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_6_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_6_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_7": "int16", "TOTAL_HTL_CHAIN_CHN_7_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_7_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_7_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_9": "int16", "TOTAL_HTL_CHAIN_CHN_9_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_9_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_9_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_10": "int16", "TOTAL_HTL_CHAIN_CHN_10_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_10_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_10_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_11": "int16", "TOTAL_HTL_CHAIN_CHN_11_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_11_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_11_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_12": "int16", "TOTAL_HTL_CHAIN_CHN_12_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_12_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_12_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_13": "int16", "TOTAL_HTL_CHAIN_CHN_13_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_13_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_13_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_14": "int16", "TOTAL_HTL_CHAIN_CHN_14_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_14_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_14_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_15": "int16", "TOTAL_HTL_CHAIN_CHN_15_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_15_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_15_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_18": "int16", "TOTAL_HTL_CHAIN_CHN_18_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_18_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_18_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_20": "int16", "TOTAL_HTL_CHAIN_CHN_20_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_20_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_20_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_22": "int16", "TOTAL_HTL_CHAIN_CHN_22_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_22_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_22_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_23": "int16", "TOTAL_HTL_CHAIN_CHN_23_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_23_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_23_GUEST_QTY": "int16", "MBR_TENURE": "int16"}
full_email_df = pd.read_csv(temp_pth, chunksize = 5000000, header = None, dtype = {i: full_email[key] for i, key in enumerate(full_email)}) #, dtype = full_email, parse_dates = ["SEND_DT"])

n = 0
i = 0
for chunk in full_email_df:
    print("#################################################")
    print(f"Chunk {i} Started -- {datetime.datetime.now()}")
    chunk.columns = col_list
    chunk = chunk.astype(full_email)
    chunk["SEND_DT"] = pd.to_datetime(chunk["SEND_DT"])
    
    chunk = pd.merge(left = chunk,
                     right = df,
                     left_on = ["HASH_NBR", "CAMPAIGN_NBR", "SEND_DT", "CLICK"],
                     right_on = ["HASH_NBR", "CAMPAIGN_NBR", "SEND_DT", "CLICK"],
                     how = "left"
                    )

    chunk.to_csv(final_df_pth, index = False, mode = 'a', header = False)
    n = n + chunk.shape[0]
    print(f"Chunk {i} Completed -- {datetime.datetime.now()}")
    print(f"ROWS PROCESSED: {n}")
    print("#################################################")
    i = i + 1
    gc.collect()
# Out:
# #################################################
# Chunk 0 Started -- 2023-04-11 11:49:51.251824
# Chunk 0 Completed -- 2023-04-11 12:00:41.835548
# ROWS PROCESSED: 5000923
# #################################################
# #################################################
# Chunk 1 Started -- 2023-04-11 12:01:52.825739
# Chunk 1 Completed -- 2023-04-11 12:12:26.454642
# ROWS PROCESSED: 10001742
# #################################################
# #################################################
# Chunk 2 Started -- 2023-04-11 12:13:42.319836
# Chunk 2 Completed -- 2023-04-11 12:24:18.743193
# ROWS PROCESSED: 15002670
# #################################################
# #################################################
# Chunk 3 Started -- 2023-04-11 12:25:32.818282
# Chunk 3 Completed -- 2023-04-11 12:36:12.544317
# ROWS PROCESSED: 20003518
# #################################################
# #################################################
# ...

# %% [markdown]
# ############################################################################################################################################################################################################################
# ############################################################################################################################################################################################################################

# %%
# %%time

print(f"Process Started -- {datetime.datetime.now()}")

n = 0
full_email = {"HASH_NBR": "object", "CAMPAIGN_NBR": "object", "UNSUB_IND": "int8", "SEND_DT": "object", "CLICK": "int8", "MBR_PRGM_ACTV": "int8", "week_of_year": "int16", "day_of_month": "int16", "day_of_year": "int16", "is_end_month": "int8", "is_start_month": "int8", "is_end_quarter": "int8", "is_start_quarter": "int8", "CC_2": "int8", "CC_3": "int8", "CC_4": "int8", "TIER_2": "int8", "TIER_3": "int8", "TIER_4": "int8", "quarter_1": "int8", "quarter_3": "int8", "quarter_4": "int8", "GNDR_1": "int8", "GNDR_2": "int8", "EN_1": "int8", "EN_2": "int8", "EN_3": "int8", "EN_4": "int8", "EN_6": "int8", "AGE_1": "int8", "AGE_2": "int8", "AGE_3": "int8", "AGE_4": "int8", "AGE_5": "int8", "INCOME_1": "int8", "INCOME_2": "int8", "INCOME_3": "int8", "INCOME_4": "int8", "INCOME_5": "int8", "January": "int8", "February": "int8", "April": "int8", "May": "int8", "June": "int8", "July": "int8", "August": "int8", "September": "int8", "October": "int8", "November": "int8", "December": "int8", "Monday": "int8", "Tuesday": "int8", "Wednesday": "int8", "Thursday": "int8", "Friday": "int8", "Saturday": "int8", "Fall": "int8", "Summer": "int8", "Winter": "int8", "Oceania": "int8", "Asia_Africa": "int8", "AUSTRALASIA_JAPAN": "int8", "CANADA": "int8", "CARIBBEAN": "int8", "EUROPE": "int8", "HONG_KONG": "int8", "INDIA_MIDDLE_EAST_AFRICA": "int8", "LATIN_AMERICA": "int8", "MAINLAND_CHINA": "int8", "MEXICO": "int8", "SOUTHEAST_ASIA_KOREA": "int8", "TAIWAN": "int8", "MACAU": "int8", "CONF_HASH_NBR": "int64", "HTL_HASH_NBR": "int64", "NUM_UNIQUE_CONF_HASH_NBR": "int16", "NUM_UNIQUE_HTL_HASH_NBR": "int16", "BUS_LEIS_IND": "int8", "STAY_REVENUE_USD": "float64", "TIME_BWTN_CONF_CKIN_DT": "int16", "TIME_BWTN_CKIN_CKOUT_DT": "int16", "CONF_DT_daysto_holiday": "int16", "CK_IN_DT_daysto_holiday": "int16", "CK_OUT_DT_daysto_holiday": "int16", "CONF_DT_nearest_holiday_dayofyear": "int16", "CK_IN_DT_nearest_holiday_dayofyear": "int16", "CK_OUT_DT_nearest_holiday_dayofyear": "int16", "DIFFERENT_CONTINENT": "int8", "MBR_TENURE_ASOF_CONF_DT": "int16", "MBR_TENURE_ASOF_CK_IN_DT": "int16", "MBR_TENURE_ASOF_CK_OUT_DT": "int16", "HTL_RGN_EMEAA": "int8", "HTL_RGN_GCHINA": "int8", "HTL_CHAIN_CATEGORY_CHN_CAT_1": "int8", "HTL_CHAIN_CATEGORY_CHN_CAT_2": "int8", "HTL_CHAIN_CATEGORY_CHN_CAT_3": "int8", "REWARD_NT_RN_1": "int8", "REWARD_NT_RN_2": "int8", "HTL_CHAIN_CHN_2": "int8", "HTL_CHAIN_CHN_3": "int8", "HTL_CHAIN_CHN_4": "int8", "HTL_CHAIN_CHN_5": "int8", "HTL_CHAIN_CHN_6": "int8", "HTL_CHAIN_CHN_7": "int8", "HTL_CHAIN_CHN_9": "int8", "HTL_CHAIN_CHN_10": "int8", "HTL_CHAIN_CHN_11": "int8", "HTL_CHAIN_CHN_12": "int8", "HTL_CHAIN_CHN_13": "int8", "HTL_CHAIN_CHN_14": "int8", "HTL_CHAIN_CHN_15": "int8", "HTL_CHAIN_CHN_18": "int8", "HTL_CHAIN_CHN_20": "int8", "HTL_CHAIN_CHN_22": "int8", "HTL_CHAIN_CHN_23": "int8", "NUM_STAYS": "int16", "TOTAL_STAY_REVENUE": "float64", "TOTAL_ROOMS": "int16", "TOTAL_GUEST_QTY": "int16", "TOTAL_TIME_BWTN_CONF_CKIN_DT": "int16", "TOTAL_TIME_BWTN_CKIN_CKOUT_DT": "int16", "TOTAL_CONF_DT_daysto_holiday": "int16", "TOTAL_CK_IN_DT_daysto_holiday": "int16", "TOTAL_CK_OUT_DT_daysto_holiday": "int16", "TOTAL_CONF_DT_nearest_holiday_dayofyear": "int16", "TOTAL_CK_IN_DT_nearest_holiday_dayofyear": "int16", "TOTAL_CK_OUT_DT_nearest_holiday_dayofyear": "int16", "NUM_BUS_LEIS_IND": "int16", "TOTAL_BUS_LEIS_IND_REVENUE": "float64", "TOTAL_BUS_LEIS_IND_ROOMS": "int16", "TOTAL_BUS_LEIS_IND_GUEST_QTY": "int16", "NUM_DIFFERENT_CONTINENT": "int16", "TOTAL_DIFFERENT_CONTINENT_REVENUE": "float64", "TOTAL_DIFFERENT_CONTINENT_ROOMS": "int16", "TOTAL_DIFFERENT_CONTINENT_GUEST_QTY": "int16", "NUM_HTL_RGN_EMEAA": "int16", "TOTAL_HTL_RGN_EMEAA_REVENUE": "float64", "TOTAL_HTL_RGN_EMEAA_ROOMS": "int16", "TOTAL_HTL_RGN_EMEAA_GUEST_QTY": "int16", "NUM_HTL_RGN_GCHINA": "int16", "TOTAL_HTL_RGN_GCHINA_REVENUE": "float64", "TOTAL_HTL_RGN_GCHINA_ROOMS": "int16", "TOTAL_HTL_RGN_GCHINA_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CATEGORY_CHN_CAT_1": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_REVENUE": "float64", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_ROOMS": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_1_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CATEGORY_CHN_CAT_2": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_REVENUE": "float64", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_ROOMS": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_2_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CATEGORY_CHN_CAT_3": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_REVENUE": "float64", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_ROOMS": "int16", "TOTAL_HTL_CHAIN_CATEGORY_CHN_CAT_3_GUEST_QTY": "int16", "NUM_REWARD_NT_RN_1": "int16", "TOTAL_REWARD_NT_RN_1_REVENUE": "float64", "TOTAL_REWARD_NT_RN_1_ROOMS": "int16", "TOTAL_REWARD_NT_RN_1_GUEST_QTY": "int16", "NUM_REWARD_NT_RN_2": "int16", "TOTAL_REWARD_NT_RN_2_REVENUE": "float64", "TOTAL_REWARD_NT_RN_2_ROOMS": "int16", "TOTAL_REWARD_NT_RN_2_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_2": "int16", "TOTAL_HTL_CHAIN_CHN_2_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_2_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_2_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_3": "int16", "TOTAL_HTL_CHAIN_CHN_3_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_3_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_3_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_4": "int16", "TOTAL_HTL_CHAIN_CHN_4_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_4_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_4_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_5": "int16", "TOTAL_HTL_CHAIN_CHN_5_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_5_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_5_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_6": "int16", "TOTAL_HTL_CHAIN_CHN_6_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_6_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_6_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_7": "int16", "TOTAL_HTL_CHAIN_CHN_7_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_7_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_7_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_9": "int16", "TOTAL_HTL_CHAIN_CHN_9_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_9_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_9_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_10": "int16", "TOTAL_HTL_CHAIN_CHN_10_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_10_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_10_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_11": "int16", "TOTAL_HTL_CHAIN_CHN_11_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_11_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_11_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_12": "int16", "TOTAL_HTL_CHAIN_CHN_12_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_12_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_12_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_13": "int16", "TOTAL_HTL_CHAIN_CHN_13_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_13_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_13_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_14": "int16", "TOTAL_HTL_CHAIN_CHN_14_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_14_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_14_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_15": "int16", "TOTAL_HTL_CHAIN_CHN_15_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_15_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_15_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_18": "int16", "TOTAL_HTL_CHAIN_CHN_18_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_18_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_18_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_20": "int16", "TOTAL_HTL_CHAIN_CHN_20_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_20_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_20_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_22": "int16", "TOTAL_HTL_CHAIN_CHN_22_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_22_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_22_GUEST_QTY": "int16", "NUM_HTL_CHAIN_CHN_23": "int16", "TOTAL_HTL_CHAIN_CHN_23_REVENUE": "float64", "TOTAL_HTL_CHAIN_CHN_23_ROOMS": "int16", "TOTAL_HTL_CHAIN_CHN_23_GUEST_QTY": "int16", "MBR_TENURE": "int16"}
df_chunk = pd.read_csv(final_df_pth, chunksize = 250000, dtype = full_email, parse_dates = ["SEND_DT"])

for i, df in enumerate(df_chunk):
    
    print("#################################################")
    print(f"Chunk {i} Started -- {datetime.datetime.now()}")
        
    df.sort_values(["HASH_NBR", "CAMPAIGN_NBR", "SEND_DT"], inplace = True)
    df.drop_duplicates(subset = ["HASH_NBR", "CAMPAIGN_NBR", "CLICK", "SEND_DT", "MBR_PRGM_ACTV", "CC_2", "CC_3", "CC_4", "TIER_2", "TIER_3", "TIER_4", "UNSUB_IND"], inplace = True, keep = "last")
    
    df_012022 = df[df["SEND_DT"] >= test_cut_date].reset_index(drop = True)
    df = df[df["SEND_DT"] < test_cut_date].reset_index(drop = True)

    if i == 0:
        df.to_csv(final_df_pth2, index = False, mode = 'w')
        df_012022.to_csv(final_01_2022_pth, index = False, mode = 'w')
    else:
        df.to_csv(final_df_pth2, index = False, mode = 'a', header = False)
        df_012022.to_csv(final_01_2022_pth, index = False, mode = 'a', header = False)
        
    n = n + df.shape[0]
    print(f"Chunk {i} Completed -- {datetime.datetime.now()}")
    print(f"ROWS PROCESSED: {'{:,}'.format(n)}")
    print("#################################################")
    
    gc.collect()

print(f"Process Completed -- {datetime.datetime.now()}")
# Out:
# Process Started -- 2023-04-11 17:07:52.256602
# #################################################
# Chunk 0 Started -- 2023-04-11 17:07:55.854046
# Chunk 0 Completed -- 2023-04-11 17:08:08.834508
# ROWS PROCESSED: 236,504
# #################################################
# #################################################
# Chunk 1 Started -- 2023-04-11 17:08:12.283697
# Chunk 1 Completed -- 2023-04-11 17:08:25.297509
# ROWS PROCESSED: 473,140
# #################################################
# #################################################
# Chunk 2 Started -- 2023-04-11 17:08:28.695275
# Chunk 2 Completed -- 2023-04-11 17:08:41.954165
# ROWS PROCESSED: 713,553
# #################################################
# #################################################
# Chunk 3 Started -- 2023-04-11 17:08:45.309580
# Chunk 3 Completed -- 2023-04-11 17:08:58.305332
# ROWS PROCESSED: 958,242
# #################################################
# ...
